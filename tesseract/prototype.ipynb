# %%
# generate test images

# !trdg -c 100 -w 5 -f 64 -na 2
# Out:
# Missing modules for handwritten text generation.
# 100%|█████████████████████████████████████████| 100/100 [00:17<00:00,  5.64it/s]

# %%
from trdg.generators import (
    GeneratorFromDict,
    GeneratorFromRandom,
    GeneratorFromStrings,
    GeneratorFromWikipedia,
)

# The generators use the same arguments as the CLI, only as parameters
generator = GeneratorFromStrings(
    ['Test1', 'Test2', 'Test3'],
    blur=2,
    random_blur=True
)

for img, lbl in generator:
    # Do something with the pillow images here.
    print(img, lbl)
    img.show()

# %%
# Library imports and tesseract path setup

import os
import random
from PIL import Image
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'

# %%
# Choose a random image from the folder and display it

# Define the folder path
folder_path = "./out"

# Get all .jpg files in the folder
jpg_files = [file for file in os.listdir(folder_path) if file.endswith('.jpg')]

# Check if there are .jpg files in the folder
if jpg_files:
    # Select a random file
    random_file = random.choice(jpg_files)
    
    # Construct the full path
    random_file_path = os.path.join(folder_path, random_file)
    
    # Open the image
    image = Image.open(random_file_path)
    
    # Show the image
    image.show()
    
    # Print the file name
    print(f"Randomly selected file: {random_file}")
else:
    print("No .jpg files found in the specified folder.")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=888x64>
# Randomly selected file: unpardonably lowlier ducally coheres ayless_66.jpg

# %%
# Extract the text from the image
text = pytesseract.image_to_string(image)
print(text)
# Out:
# unpardonably lowlier ducally coheres ayless

# %%
# Display the extracted text
# The following files are not generated by the trdg library.
# source: https://www.mattmahoney.net/ocr/

numbers = Image.open("../test_images/numbers_gs150.jpg")
plaid = Image.open("../test_images/plaid_c150.jpg")
stock = Image.open("../test_images/stock_gs200.jpg")

numbers.show()
print(pytesseract.image_to_string(numbers))

plaid.show()
print(pytesseract.image_to_string(plaid))

stock.show()
print(pytesseract.image_to_string(stock))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=527x1122>
#
#
# 3.75 miles | 7.5 11.25 15.0
# 30.0 33.75 37.5 41,25
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x940>
#
#
# CENTER
# FOR THE i hiericdomiom Maloue
#
# January 6-29
#
# Fri & Saturdays at 8
# Sander Matinees at 2 pes
#
# _ Tickets: 723-8698
#
# | www.henegar.org pees 5 Naame tard
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=626x580>
